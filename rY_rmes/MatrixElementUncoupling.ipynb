# %% [markdown]
# # Multi-shell coefficients of fractional parentage

# %% [markdown]
# $$ _{\rho_1}\Big\langle[f'_{-}]\otimes[f'_{+}],\hspace{1mm}(\lambda'_{-}\mu'_{-})\otimes (\lambda'_{+}\mu'_{+}),(\lambda'\mu'),K',L',M_{L'},[\bar{f}'_{-}]\otimes[\bar{f}'_{+}],S'_{-}\otimes S'_{+},S',M_{S'}\Big|
# \\\times a^{\dagger}_{(\eta'0)l'm_{l'}\frac{1}{2}m_{s'}}\Big|[f''_{-}]\otimes[f''_{+}],\hspace{1mm}(\lambda''_{-}\mu''_{-})\otimes (\lambda''_{+}\mu''_{+}),(\lambda''\mu''),K'',L'',M_{L''},[\bar{f}''_{-}]\otimes[\bar{f}''_{+}],S''_{-}\otimes S''_{+},S'',M_{S''}\Big\rangle_{\rho_2}
# \\ = \sum_{\substack{K'_{-}, L'_{-},M_{L'_{-}},K'_{+}, L'_{+},M_{L'_{+}} \\ S'_{-},M_{S'_{-}},S'_{+},M_{S'_{+}} \\ K''_{-}, L''_{-},M_{L''_{-}},K''_{+}, L''_{+},M_{L''_{+}}} \\S''_{-},M_{S''_{-}},S''_{+},M_{S''_{+}}}\langle(\lambda'_{-}\mu'_{-}),K'_{-}, L'_{-};(\lambda'_{+}\mu'_{+}), K'_{+}, L'_{+}||(\lambda'\mu'),K',L'\rangle_{\rho_1}\langle L'_{-},M_{L'_{-}},L'_{+},M_{L'_{+}}|L',M_{L'}\rangle\langle S'_{-},M_{S'_{-}},S'_{+},M_{S'_{+}}|S',M_{S'}\rangle
# \\ \times\langle(\lambda''_{-}\mu''_{-}),K''_{-}, L''_{-};(\lambda''_{+}\mu''_{+}), K''_{+}, L''_{+}||(\lambda''\mu''),K'',L''\rangle_{\rho_2}\langle L''_{-},M_{L''_{-}},L''_{+},M_{L''_{+}}|L'',M_{L''}\rangle\langle S''_{-},M_{S''_{-}},S''_{+},M_{S''_{+}}|S'',M_{S''}\rangle
# \\\times\Bigg(\Big\langle[f'_{-}], (\lambda'_{-}\mu'_{-}), K'_{-}, L'_{-}, M_{L'_{-}}, [\bar{f}'_{-}], S'_{-}, M_{S'_{-}} \Big| \otimes  \Big\langle [f'_{+}], (\lambda'_{+}\mu'_{+}), K'_{+}, L'_{+}, M_{L'_{+}}, [\bar{f}'_{+}], S'_{+}, M_{S'_{+}} \Big|\Bigg)
# \\\times a^{\dagger}_{(\eta'0)l'm_{l'}\frac{1}{2}m_{s'}}
# \Bigg(\Big|[f''_{-}], (\lambda''_{-}\mu''_{-}), K''_{-}, L''_{-}, M_{L''_{-}}, [\bar{f}''_{-}], S''_{-}, M_{S''_{-}}\Big\rangle  \otimes  \Big| [f''_{+}], (\lambda''_{+}\mu''_{+}), K''_{+}, L''_{+}, M_{L''_{+}}, [\bar{f}''_{+}], S''_{+}, M_{S''_{+}}\Big\rangle \Bigg)
# \\ = \langle(\lambda''\mu''),K'', L'';(\eta',0), 0, l'||(\lambda'\mu'),K',L'\rangle_{\rho=1}\frac{\langle L'',M_{L''},l',m_{l'}|L',M_{L'}\rangle\langle S'',M_{S''},\frac{1}{2},m_{s'}|S',M_{S'}\rangle}{\sqrt{2S'+1}}\\\Big\langle[f'_{-}]\otimes[f'_{+}],\hspace{1mm}(\lambda'_{-}\mu'_{-})\otimes (\lambda'_{+}\mu'_{+}),(\lambda'\mu'),S'\Big|\Big|\Big|a^{\dagger}_{(\eta',0)\frac{1}{2}}\Big|\Big|\Big|[f''_{-}]\otimes[f''_{+}],\hspace{1mm}(\lambda''_{-}\mu''_{-})\otimes (\lambda''_{+}\mu''_{+}),(\lambda''\mu''),S''\Big\rangle_{\rho=1}$$
#
# For the following particular case of the proton exited RME
#
# $$_{\rho_1}\Big\langle[2^3,1]\otimes[1],\hspace{1mm}(25,2)\otimes (6,0),(31,2),K',L',M_{L'},[4,3]\otimes[1],\frac{1}{2}\otimes \frac{1}{2},0,0\Big|\\\times a^{\dagger}_{(6,0)l'm_{l'}\frac{1}{2}m_{s'}}\Big|[2^3,1]\otimes[0],\hspace{1mm}(25,2)\otimes (0,0),(25,2),K'',L'',M_{L''},[4,3]\otimes[0],\frac{1}{2}\otimes 0,\frac{1}{2},M_{S''}\Big\rangle_{\rho_2}
# \\ = \sum_{\substack{K'_{-}, L'_{-},M_{L'_{-}},K'_{+}, L'_{+},M_{L'_{+}} \\ S'_{-},M_{S'_{-}},S'_{+},M_{S'_{+}} \\ K''_{-}, L''_{-},M_{L''_{-}},K''_{+}, L''_{+},M_{L''_{+}}} \\S''_{-},M_{S''_{-}},S''_{+},M_{S''_{+}}}\langle(25,2),K'_{-}, L'_{-};(6,0), K'_{+}, L'_{+}||(31,2),K',L'\rangle_{\rho_1}\langle L'_{-},M_{L'_{-}},L'_{+},M_{L'_{+}}|L',M_{L'}\rangle\langle \frac{1}{2},M_{S'_{-}},\frac{1}{2},M_{S'_{+}}|0,0\rangle
# \\ \times\langle(25,2),K''_{-}, L''_{-};(0,0), K''_{+}, L''_{+}||(25,2),K'',L''\rangle_{\rho_2}\langle L''_{-},M_{L''_{-}},L''_{+},M_{L''_{+}}|L'',M_{L''}\rangle\langle \frac{1}{2},M_{S''_{-}},0,0|\frac{1}{2},M_{S''}\rangle
# \\\times\Big\langle [1], (6,0), K'_{+}, L'_{+}, M_{L'_{+}}, [1], \frac{1}{2}, M_{S'_{+}} \Big|
#  a^{\dagger}_{(6,0)l'm_{l'}\frac{1}{2}m_{s'}}
# \Big| [0], (0,0), 0, 0,0, [0], 0, 0\Big\rangle
# \\
# \\ = \sum_{\substack{K'_{-}, L'_{-},M_{L'_{-}},K'_{+}, L'_{+},M_{L'_{+}}}}\langle(25,2),K'_{-}, L'_{-};(6,0), 0, l'||(31,2),K',L'\rangle_{\rho_1}\langle L'_{-},M_{L'_{-}},l',m_{l'}|L',M_{L'}\rangle\frac{(-1)}{\sqrt{2}}
# \\ \times\langle(25,2),K'', L'';(0,0), 0,0||(25,2),K'',L''\rangle_{\rho_2}\langle L'',M_{L''},0,0|L'',M_{L''}\rangle\frac{1}{\sqrt{2}}
# \\
# \\ = \sum_{\substack{K'_{-}, L'_{-},M_{L'_{-}}, l',m_{l'}}}\langle(25,2),K'_{-}, L'_{-};(6,0), 0, l'||(31,2),K',L'\rangle_{\rho_1}\langle L'_{-},M_{L'_{-}},l',m_{l'}|L',M_{L'}\rangle\frac{(-1)}{\sqrt{2}}
# \frac{1}{\sqrt{2}}
# $$
#
#
# Apply Wigner-Eckart theorem in the left hand side
#
#
# $$
# \\ = \langle(25,2),K'', L'';(6,0), 0, l'||(31,2),K',L'\rangle_{\rho=1}\langle L'',M_{L''},l',m_{l'}|L',M_{L'}\rangle\frac{(-1)}{\sqrt{2}}\\\Big\langle[2^3,1]\otimes[1],\hspace{1mm}(25,2)\otimes (6,0),(31,2),0\Big|\Big|\Big|a^{\dagger}_{(6,0)\frac{1}{2}}\Big|\Big|\Big|[2^3,1]\otimes[0],\hspace{1mm}(25,2)\otimes (0,0),(25,2),\frac{1}{2}\Big\rangle_{\rho=1}
# \\
# $$
#
# Simplification and solving for the rme
#
# $$
# \Big\langle[2^3,1]\otimes[1],\hspace{1mm}(25,2)\otimes (6,0),(31,2),0\Big|\Big|\Big|a^{\dagger}_{(6,0)\frac{1}{2}}\Big|\Big|\Big|[2^3,1]\otimes[0],\hspace{1mm}(25,2)\otimes (0,0),(25,2),\frac{1}{2}\Big\rangle_{\rho=1} =
# \frac{\sum_{\substack{K'_{-}, L'_{-},M_{L'_{-}}, l',m_{l'}}}\langle(25,2),K'_{-}, L'_{-};(6,0), 0, l'||(31,2),K',L'\rangle_{\rho_1}\langle L'_{-},M_{L'_{-}},l',m_{l'}|L',M_{L'}\rangle\frac{1}{\sqrt{2}}}
# {\langle(25,2),K'', L'';(6,0), 0, l'||(31,2),K',L'\rangle_{\rho=1}\langle L'',M_{L''},l',m_{l'}|L',M_{L'}\rangle}
# $$
#
# Choose particular values for $K', L', M_{L'}, K'', L'', M_{L''}, l', m_{l'}$ in the denominator
#
# $$
# \Big\langle[2^3,1]\otimes[1],\hspace{1mm}(25,2)\otimes (6,0),(31,2),0\Big|\Big|\Big|a^{\dagger}_{(6,0)\frac{1}{2}}\Big|\Big|\Big|[2^3,1]\otimes[0],\hspace{1mm}(25,2)\otimes (0,0),(25,2),\frac{1}{2}\Big\rangle_{\rho=1} =
# \frac{\sum_{\substack{K'_{-}, L'_{-},M_{L'_{-}}, l',m_{l'}}}\langle(25,2),K'_{-}, L'_{-};(6,0), 0, l'||(31,2),K',L'\rangle_{\rho_1}\langle L'_{-},M_{L'_{-}},l',m_{l'}|L',M_{L'}\rangle}
# {\sqrt{2}\langle(25,2),0, 1;(6,0), 0, 0||(31,2),0,1\rangle_{\rho=1}\langle 1,0,0,0|1,0\rangle}
# $$

# %%
import numpy as np
import pandas as pd
from sympy.physics.quantum.cg import CG

# %%
# Function to upload SU(3) Wigner coefficients from the program's output format
# path is the direction of the file
# l0, m0  are the labels of the irrep of the one-body operator coupling

def load_SU3_Wigner_file(path,name):
    
    # Filename depending on irrep
    filename = path + name

    # Open file
    with open(filename + '.txt') as f:
        lines = f.readlines()
        
    # SU3 irreps loaded
    l1, m1 = int(lines[2].split(" ")[0]), int(lines[2].split(" ")[1]) 
    l2, m2 = int(lines[6].split(" ")[0]), int(lines[6].split(" ")[1]) 
    l12, m12 = int(lines[10].split(" ")[0]), int(lines[10].split(" ")[1]) 
    
    # Values and labels stored
    values = [list(filter(lambda x: x != '', l.split(" "))) for l in lines[15:]]
    
    # Column names and multiplicidades
    cols = ["k1", "L1", "k2", "L2", "k3", "L3"]
    rhos = []
    for i in range(1,len(values[0])-5):
        cols.append("rho{0}".format(i))
        rhos.append("rho{0}".format(i))
        
    # Values stored
    values_df = pd.DataFrame(np.array(values), columns = cols)
    values_df[["k1", "L1", "k2", "L2", "k3", "L3"]] = values_df[["k1", "L1", "k2", "L2", "k3", "L3"]].astype(int)
    values_df[rhos] = values_df[rhos].astype(float)

    return SU3_Wigner(values_df)
    
# Class to store the SU(3) Wigner values 
class SU3_Wigner:
    
    def __init__(self, values):

        self.values = values

# %%
#Load and store of files for proton excited rme
Wc11 = load_SU3_Wigner_file("./Multishell_cfp/", "coeffs_Kp=0_Lp=1")   # K=1 in Dytrych program
Wc12 = load_SU3_Wigner_file("./Multishell_cfp/", "coeffs_Kp=2_Lp=2")   # K=1 in Dytrych program

Wc12.values
# Out:
#     k1  L1  k2  L2  k3  L3      rho1
# 0    1   1   1   2   1   2  0.000000
# 1    1   2   1   0   1   2  0.416582
# 2    1   2   1   2   1   2  0.406543
# 3    1   2   1   4   1   2  0.054818
# 4    1   3   1   2   1   2 -0.003718
# 5    2   3   1   2   1   2 -0.509147
# 6    1   3   1   4   1   2 -0.001418
# 7    2   3   1   4   1   2 -0.194181
# 8    1   4   1   2   1   2  0.309786
# 9    1   4   1   4   1   2  0.320606
# 10   1   4   1   6   1   2  0.036968
# 11   1   5   1   4   1   2 -0.006024
# 12   2   5   1   4   1   2 -0.307958
# 13   1   5   1   6   1   2 -0.001786
# 14   2   5   1   6   1   2 -0.091309
# 15   1   6   1   4   1   2  0.166240
# 16   1   6   1   6   1   2  0.125666
# 17   1   7   1   6   1   2 -0.004067
# 18   2   7   1   6   1   2 -0.107611
# 19   1   8   1   6   1   2  0.053510

# %%
Wc11.values.to_csv("./Multishell_cfp_coefficients_tables/coeffs_Kp=0_Lp=1.csv")
Wc12.values.to_csv("./Multishell_cfp_coefficients_tables/coeffs_Kp=2_Lp=2.csv")

# %%
# Function to compute the numerator of the multi-shell cfp expansion
# Kp, Lp, Mp are free to choose quantum numbers
def numerator(Kp, Lp, MLp):
    
    num = 0
    coeffs = globals()["Wc"+str(Kp)+str(Lp)].values
    
    for i in range(0, len(coeffs)):
        
        # Value of coefficient
        coeff = coeffs["rho1"][i]
        
        # Quantum numbers
        Lminus = coeffs["L1"][i]
        l = coeffs["L2"][i]
                
        # Sum over the SO(3) CG coefficients 
        proy = 0
        
        for ml in range(-l, l+1):
            for MLminus in range(-Lminus, Lminus+1):
                proy += float(CG(j1=Lminus, m1=MLminus, j2=l, m2=ml, j3=Lp, m3=MLp).doit())
        
        # The products of coefficient and sum over SO(3) CG coefficients are accumulated
        num += proy*coeff
        
    return num

# Function to compute the coupled multi-shell cfp
def ms_cfp(Kpp, Lpp, MLpp, Kp, Lp, MLp, lp, mlp):
    
    # Coefficients
    coeffs = globals()["Wc"+str(Kp)+str(Lp)].values

    # Coefficient of denominator
    coeff = float(coeffs[(coeffs["k1"]==Kpp) & (coeffs["L1"]==Lpp) & (coeffs["L2"]==lp) & (coeffs["k3"]==Kp) & (coeffs["L3"]==Lp)].rho1)
        
    return numerator(Kp, Lp, MLp)/(np.sqrt(2)*coeff*float(CG(j1=Lpp, m1=MLpp, j2=lp, m2=mlp, j3=Lp, m3=MLp).doit()))

# %%
ms_cfp(1,1,0,1,1,0,0,0)
# Out:
# 0.5630097051882366

# %%
ms_cfp(1,2,0,1,2,0,0,0)
# Out:
# 2.196946150191427

# %%
numerator(1, 1, 1)/(np.sqrt(2)*0.416582*float(CG(j1=1, m1=0, j2=0, m2=0, j3=1, m3=0).doit()))
# Out:
# 0.5854704847197031

# %%
numerator(1, 2, 2)/(np.sqrt(2)*0.416582*float(CG(j1=2, m1=0, j2=0, m2=0, j3=2, m3=0).doit()))
# Out:
# 1.3437239392944116
